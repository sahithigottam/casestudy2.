# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
filename = "/Users/sahithi/Desktop/week_6/StudentsPerformance.csv"

# %%
df = pd.read_csv(filename)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# # Find out how many males and females participated in the test.

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# # What do you think about the students' parental level of education?

# %%
df.rename(columns={"parental level of education":"parental_education"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gender                   1000 non-null   object
#  1   race/ethnicity           1000 non-null   object
#  2   parental_education       1000 non-null   object
#  3   lunch                    1000 non-null   object
#  4   test preparation course  1000 non-null   object
#  5   math score               1000 non-null   int64
#  6   reading score            1000 non-null   int64
#  7   writing score            1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df['parental_education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental_education, dtype: int64

# %% [markdown]
# mostly all the parents are educated and less number of them have done masters degree

# %% [markdown]
# # Who scores the most on average for math, reading and writing based on
# # Gender

# %%
df2  = df.groupby('gender', as_index=False)['math score','writing score','reading score'].mean()
# Out:
# /var/folders/fj/q35yrt4d19g2nw3g9mdzw2980000gp/T/ipykernel_17783/744284538.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2  = df.groupby('gender', as_index=False)['math score','writing score','reading score'].mean()

# %%
df2
# Out:
#    gender  math score  writing score  reading score
# 0  female   63.376448      72.467181      72.590734
# 1    male   68.821577      63.446058      65.545643

# %% [markdown]
# by looking at the small table, its clear that in maths male students acheived high score but in the writing and reading female stiudents achieved it.

# %% [markdown]
# # Who scores the most on average for math, reading and writing based on
# #Test preparation course

# %%
df3  = df.groupby('test preparation course', as_index=False)['math score','writing score','reading score'].mean()
# Out:
# /var/folders/fj/q35yrt4d19g2nw3g9mdzw2980000gp/T/ipykernel_17783/1437569302.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df3  = df.groupby('test preparation course', as_index=False)['math score','writing score','reading score'].mean()

# %%
df3
# Out:
#   test preparation course  math score  writing score  reading score
# 0               completed    69.96648      74.684358      74.175978
# 1                    none    63.78972      64.457944      66.417445

# %% [markdown]
# its totally clear that the students who finished the course have high average compared to the once who did not

# %% [markdown]
# # What do you think about the scoring variation for math, reading and writing
# #based on Gender

# %%
var_gm=statistics.variance(variance_g['math score','writing score','reading score'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 var_gm=statistics.variance(variance_g['math score','writing score','reading score'])
#
# NameError: name 'variance_g' is not defined

# %%
df3=df.groupby('gender',as_index=False)['reading score','writing score','math score'].std()
# Out:
# /var/folders/fj/q35yrt4d19g2nw3g9mdzw2980000gp/T/ipykernel_17783/1869501669.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df3=df.groupby('gender',as_index=False)['reading score','writing score','math score'].std()

# %%
df3
# Out:
#    gender  reading score  writing score  math score
# 0  female      14.411018      14.844842   16.029928
# 1    male      14.149594      14.227225   14.556411

# %% [markdown]
# only the variation for math is score different compared to other 2 subjects

# %%
df4=df.groupby('test preparation course',as_index=False)['reading score','writing score','math score'].std()
# Out:
# /var/folders/fj/q35yrt4d19g2nw3g9mdzw2980000gp/T/ipykernel_17783/3737320077.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df4=df.groupby('test preparation course',as_index=False)['reading score','writing score','math score'].std()

# %%
df4
# Out:
#   test preparation course  reading score  writing score  math score
# 0               completed      13.537572      13.236412   14.521847
# 1                    none      14.608896      15.041667   15.705689

# %% [markdown]
# variation of not completed scores is high compared to the completed ones

# %% [markdown]
# # 5. The management needs your help to give bonus points to the top 25% of students based on their maths score, so how will you help the management to achieve this.

# %%
df4 = df.sort_values("math score",ascending = False)

# %%
df4
# Out:
#      gender race/ethnicity  parental_education         lunch  \
# 999    male        group E   bachelor's degree      standard
# 996    male        group A        some college      standard
# 515  female        group E        some college      standard
# 517  female        group E  associate's degree      standard
# 516  female        group E   bachelor's degree      standard
# ..      ...            ...                 ...           ...
# 2    female        group B    some high school  free/reduced
# 51   female        group C    some high school  free/reduced
# 3    female        group B        some college      standard
# 1    female        group B         high school  free/reduced
# 0    female        group C    some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 999               completed         100            100            100
# 996               completed         100             96             86
# ...

# %%
df4.head(25)
# Out:
#      gender race/ethnicity  parental_education         lunch  \
# 999    male        group E   bachelor's degree      standard
# 996    male        group A        some college      standard
# 515  female        group E        some college      standard
# 517  female        group E  associate's degree      standard
# 516  female        group E   bachelor's degree      standard
# 997    male        group D        some college      standard
# 998    male        group E  associate's degree  free/reduced
# 995    male        group E        some college      standard
# 513  female        group E   bachelor's degree      standard
# 514  female        group E         high school      standard
# 994    male        group C  associate's degree      standard
# 993    male        group C        some college      standard
# 512  female        group D        some college      standard
# 992    male        group E  associate's degree      standard
# ...

# %% [markdown]
# these are the top 25 students whith hieghest marks in maths
